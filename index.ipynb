# %% [markdown]
# # 🌈🌌🔭 ASTR3520 🌈🌌🔭
#
# ## Spectroscopic Handbook
# Welcome! These pages collect some tools, resources, and code snippets that might be helpful in analyzing data from either the charming old spectrograph on the SBO 0.6m or the slightly fancier KOSMOS spectrograph on the APO 3.5m.
